# %%
# !git clone https://TaiQuach123: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@github.com/TaiQuach123/Face_Surveillance.git
# Out:
# Cloning into 'Face_Surveillance'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 86 (delta 15), reused 75 (delta 11), pack-reused 0
# Unpacking objects: 100% (86/86), 5.78 MiB | 11.17 MiB/s, done.

# %%
# %cd /kaggle/working/Face_Surveillance
# Out:
# /kaggle/working/Face_Surveillance

# %%
# !pip install wandb

import wandb
wandb.login()
# Out:
# ...
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python train_recognition.py --network 'mobilenet' --train_root '/kaggle/input/casia-dataset/CASIA-align-112x112/CASIA-align-112x112' --save_train_txt '/kaggle/input/casia-dataset/casia_text_file.txt' --lfw_val_root '/kaggle/input/casia-dataset/lfw-aligned/lfw-aligned' --lfw_val_txt '/kaggle/input/casia-dataset/lfw_test_pair.txt' --lr 5e-3 --batch_size 128 --epochs 50
# Out:
# wandb: Currently logged in as: taiquach123471 (taiquach). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.17.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.17.4
# wandb: Run data is saved locally in /kaggle/working/Face_Surveillance/wandb/run-20240812_055348-ywouc9sc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run eternal-blaze-28
# wandb: ⭐️ View project at https://wandb.ai/taiquach/FaceRecognition
# wandb: 🚀 View run at https://wandb.ai/taiquach/FaceRecognition/runs/ywouc9sc
# Training.........
# Epoch:1/50 || Epoch_iter: 100/3560 || Iter: 100/178000 || LR: 0.0050 || Train Loss: 43.5221  || Batchtime: 0.1525 s || ETA: 7:32:15
# Epoch:1/50 || Epoch_iter: 200/3560 || Iter: 200/178000 || LR: 0.0050 || Train Loss: 43.7330  || Batchtime: 0.1536 s || ETA: 7:35:12
# ...

# %%
from IPython.display import FileLink

# %cd /kaggle/working
# Out:
# /kaggle/working

# %%
FileLink('Face_Surveillance/weights/recognition/best_checkpoint_mobilenet.pth')
# Out:
# /kaggle/working/Face_Surveillance/weights/recognition/best_checkpoint_mobilenet.pth

# %%
FileLink('Face_Surveillance/checkpoints/recognition/current_checkpoint_mobilenet.pth')
# Out:
# /kaggle/working/Face_Surveillance/checkpoints/recognition/current_checkpoint_mobilenet.pth
